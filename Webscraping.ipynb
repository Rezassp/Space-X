# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
ulr="https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"
response=requests.get(ulr)

# %%
bs=BeautifulSoup(response.text,"html5lib")

# %%
my_table=bs.find('table',{'id':'2023ytd'})

# %%
column_names = []
headers=my_table.find_all('th')
for col in headers:
    col_name=col.get_text().strip()
    if col_name is not None and len(col_name)>0 and not(col_name.isdigit()):
        column_names.append(col_name)

# %%
 column_names
# Out:
# ['Flight No.',
#  'Date andtime (UTC)',
#  'Version,booster[f]',
#  'Launchsite',
#  'Payload[g]',
#  'Payload mass',
#  'Orbit',
#  'Customer',
#  'Launchoutcome',
#  'Boosterlanding',
#  'FH 5',
#  'FH 6',
#  'FH 7',
#  'FH 8',
#  'FH 9']

# %%
cell_columns=[x for x in column_names if x not in ['Flight No.']]
cell_columns
# Out:
# ['Date andtime (UTC)',
#  'Version,booster[f]',
#  'Launchsite',
#  'Payload[g]',
#  'Payload mass',
#  'Orbit',
#  'Customer',
#  'Launchoutcome',
#  'Boosterlanding',
#  'FH 5',
#  'FH 6',
#  'FH 7',
#  'FH 8',
#  'FH 9']

# %%
launch_dict= dict.fromkeys(column_names)
launch_dict={col: [] for col in column_names}
launch_dict
# Out:
# {'Flight No.': [],
#  'Date andtime (UTC)': [],
#  'Version,booster[f]': [],
#  'Launchsite': [],
#  'Payload[g]': [],
#  'Payload mass': [],
#  'Orbit': [],
#  'Customer': [],
#  'Launchoutcome': [],
#  'Boosterlanding': [],
#  'FH 5': [],
#  'FH 6': [],
#  'FH 7': [],
#  'FH 8': [],
#  'FH 9': []}

# %%
rows=my_table.find_all('tr')

# %%
for row in rows:
    cells=row.find_all('td')
    if row.th and row.th.get_text().strip()!='Flight No.':
        launch_dict['Flight No.'].append(row.th.get_text().strip())
        for col,cell in zip(cell_columns,cells):
            launch_dict[col].append(cell.get_text().strip())

# %%
launch_dict = {key: value for key, value in launch_dict.items() if len(value) > 0}

# %%
df=pd.DataFrame(launch_dict)

# %%
df
# Out:
#    Flight No.           Date andtime (UTC)                 Version,booster[f]  \
# 0         195     January 3, 202314:56[17]                      F9 B5B1060.15
# 1         196    January 10, 202304:50[23]                       F9 B5B1076.2
# 2        FH 5    January 15, 202322:56[29]        Falcon Heavy B5B1070 (core)
# 3         197    January 18, 202312:24[33]                       F9 B5B1077.2
# 4         198    January 19, 202315:43[39]                       F9 B5B1075.1
# ..        ...                          ...                                ...
# 91        282  December 19, 202304:01[207]                       F9 B5B1081.3
# 92        283  December 23, 202305:33[208]                      F9 B5B1058.19
# 93        284  December 24, 202313:11[210]                       F9 B5B1075.8
# 94       FH 9  December 29, 202301:07[213]  Falcon Heavy B5 B1084 (core)[214]
# 95        285  December 29, 202304:01[221]                      F9 B5B1069.12
#
#                 Launchsite                                      Payload[g]  \
# 0   Cape Canaveral, SLC‑40  Transporter-6 (115 payload smallsat rideshare)
# 1   Cape Canaveral, SLC‑40                       OneWeb 16 (40 satellites)
# 2          Kennedy, LC‑39A                      USSF-67 (CBAS-2 & LDPE-3A)
# 3   Cape Canaveral, SLC‑40                          USA-343 (GPS-III SV06)
# 4       Vandenberg, SLC‑4E             Starlink: Group 2-4 (51 satellites)
# ..                     ...                                             ...
# 91  Cape Canaveral, SLC‑40            Starlink: Group 6-34 (23 satellites)
# 92  Cape Canaveral, SLC‑40            Starlink: Group 6-32 (23 satellites)
# 93      Vandenberg, SLC‑4E                                SARah 2 & 3[211]
# 94         Kennedy, LC‑39A                    USSF-52 (Boeing X-37B OTV-7)
# 95  Cape Canaveral, SLC‑40            Starlink: Group 6-36 (23 satellites)
#
#                          Payload mass                     Orbit  \
# 0                          Unknown[h]                       SSO
# 1                6,000 kg (13,000 lb)                 Polar LEO
# 2                ~3,750 kg (8,270 lb)                       GEO
# 3                 4,352 kg (9,595 lb)                       MEO
# 4               15,000 kg (33,000 lb)                       LEO
# ..                                ...                       ...
# 91             ~16,800 kg (37,000 lb)                       LEO
# 92             ~16,800 kg (37,000 lb)                       LEO
# 93               ~3,600 kg (7,900 lb)                       SSO
# 94  6,350 kg (14,000 lb)+ OTV payload  High Elliptical HEO[215]
# 95             ~16,800 kg (37,000 lb)                       LEO
#
#                                              Customer Launchoutcome  \
# 0                                             Various       Success
# 1                                              OneWeb       Success
# 2                                                USSF       Success
# 3                                                USSF       Success
# 4                                              SpaceX       Success
# ..                                                ...           ...
# 91                                             SpaceX       Success
# 92                                             SpaceX       Success
# 93                        German Intelligence Service       Success
# 94  Department of the Air Force RapidCapabilities ...       Success
# 95                                             SpaceX       Success
#
#             Boosterlanding
# 0           Success (LZ‑1)
# 1           Success (LZ‑1)
# 2               No attempt
# 3           Success (JRTI)
# 4         Success (OCISLY)
# ..                     ...
# 91          Success (ASOG)
# 92  Partial failure (JRTI)
# 93          Success (LZ‑4)
# 94              No attempt
# 95          Success (ASOG)
#
# [96 rows x 10 columns]

# %%
df[['Date','Time']]=df['Date andtime (UTC)'].str.extract(r'^(.*?\d{4})(\d{2}:\d{2})')

# %%
df['Payload mass(Kg)']=df['Payload mass'].str.extract(r'~?([\d,]+)\s*kg')[0].str.replace(',','',regex=False).astype(float)

# %%
df.drop(['Date andtime (UTC)','Payload mass'],axis=1,inplace=True)

# %%
df
# Out:
#    Flight No.                 Version,booster[f]              Launchsite  \
# 0         195                      F9 B5B1060.15  Cape Canaveral, SLC‑40
# 1         196                       F9 B5B1076.2  Cape Canaveral, SLC‑40
# 2        FH 5        Falcon Heavy B5B1070 (core)         Kennedy, LC‑39A
# 3         197                       F9 B5B1077.2  Cape Canaveral, SLC‑40
# 4         198                       F9 B5B1075.1      Vandenberg, SLC‑4E
# ..        ...                                ...                     ...
# 91        282                       F9 B5B1081.3  Cape Canaveral, SLC‑40
# 92        283                      F9 B5B1058.19  Cape Canaveral, SLC‑40
# 93        284                       F9 B5B1075.8      Vandenberg, SLC‑4E
# 94       FH 9  Falcon Heavy B5 B1084 (core)[214]         Kennedy, LC‑39A
# 95        285                      F9 B5B1069.12  Cape Canaveral, SLC‑40
#
#                                         Payload[g]                     Orbit  \
# 0   Transporter-6 (115 payload smallsat rideshare)                       SSO
# 1                        OneWeb 16 (40 satellites)                 Polar LEO
# 2                       USSF-67 (CBAS-2 & LDPE-3A)                       GEO
# 3                           USA-343 (GPS-III SV06)                       MEO
# 4              Starlink: Group 2-4 (51 satellites)                       LEO
# ..                                             ...                       ...
# 91            Starlink: Group 6-34 (23 satellites)                       LEO
# 92            Starlink: Group 6-32 (23 satellites)                       LEO
# 93                                SARah 2 & 3[211]                       SSO
# 94                    USSF-52 (Boeing X-37B OTV-7)  High Elliptical HEO[215]
# 95            Starlink: Group 6-36 (23 satellites)                       LEO
#
#                                              Customer Launchoutcome  \
# 0                                             Various       Success
# 1                                              OneWeb       Success
# 2                                                USSF       Success
# 3                                                USSF       Success
# 4                                              SpaceX       Success
# ..                                                ...           ...
# 91                                             SpaceX       Success
# 92                                             SpaceX       Success
# 93                        German Intelligence Service       Success
# 94  Department of the Air Force RapidCapabilities ...       Success
# 95                                             SpaceX       Success
#
#             Boosterlanding               Date   Time  Payload mass(Kg)
# 0           Success (LZ‑1)    January 3, 2023  14:56               NaN
# 1           Success (LZ‑1)   January 10, 2023  04:50            6000.0
# 2               No attempt   January 15, 2023  22:56            3750.0
# 3           Success (JRTI)   January 18, 2023  12:24            4352.0
# 4         Success (OCISLY)   January 19, 2023  15:43           15000.0
# ..                     ...                ...    ...               ...
# 91          Success (ASOG)  December 19, 2023  04:01           16800.0
# 92  Partial failure (JRTI)  December 23, 2023  05:33           16800.0
# 93          Success (LZ‑4)  December 24, 2023  13:11            3600.0
# 94              No attempt  December 29, 2023  01:07            6350.0
# 95          Success (ASOG)  December 29, 2023  04:01           16800.0
#
# [96 rows x 11 columns]

# %%
df.to_csv('spacex_web_scraped.csv',index=False)
